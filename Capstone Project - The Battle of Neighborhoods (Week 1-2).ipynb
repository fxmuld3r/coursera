# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1-2)

# %% [markdown]
# ## Business Problem section

# %% [markdown]
# ### Background

# %% [markdown]
# Italian immigration to Brazil peaked between 1880 and 1930. Italo-Brazilians are spread mainly across the southern and southeastern states of Brazil. Italo-Brazilians are descendants of the huge mass of Italian immigrants who arrived in Brazil between 1870 and 1960. There are no concrete data on the number of descendants of Italians in Brazil.
# Immigration directly influenced the local cuisine of the southern provinces of Brazil, a region that received the greatest number of people.
# The city of Rio de Janeiro, despite not having received a large number of immigrants, was influenced by the tourism of Italian citizens, who periodically visit the city.

# %% [markdown]
# The rich and varied Italian cuisine, distinct in the various regions of the country, influenced the cuisine of practically the rest of the world. In the case of Brazilian cuisine, for example, the influence occurred through Italian immigration in the period between 1880 and 1930. Immigrants mixed the flavors and aromas of the homeland with the ingredients offered by the new land, adding the recipes from the different regions of Italy. developing them on Sunday lunches, which brought together several families, from different regions, in the same backyard.
# In Brazil there are many Italian restaurants with a menu full of delicious pasta, but for those who want to enjoy a good and unhealthy meal, it is advisable to pay attention to two important points: quality of the place and quality of food.

# %% [markdown]
# ### Business Problem

# %% [markdown]
# Italian restaurants are spread out in large Brazilian centers, which increases competition. That way, we reach the big goal.
#
# If a company specialized in food needs a consultancy on opening a restaurant in a Brazilian capital, which capital to indicate?
# If the big prerequisite is the opening of a restaurant in a populous region with little competition, which city should we indicate.
#
# A restaurant consultancy will help the company to better understand its reality, bring a new view on the competition and lead the company strategically to the creation of a new establishment, which will help in obtaining results.

# %% [markdown]
# ### Data section

# %% [markdown]
# Based on immigration surveys (http://www.imigrantesitalianos.com.br), the most populous Brazilian capitals with the largest number of Italian immigrants were selected:
#
# - Sao Paulo
# - Porto Alegre
# - Florianópolis
# - Curitiba
# - Rio de Janeiro
#
# Such data help in the application analysis for the opening of a new restaurant.

# %% [markdown]
# ### Methodology section

# %% [markdown]
# We will use the FourSquare API to collect data about restaurants in five major Brazilian cities. The data are plotted on a map to assist in the analysis of distance between restaurants, a prerequisite of the analysis for starting a business.
# The quadrangular limits us to a maximum of 100 locations per consultation. The analysis focused only on the five cities mentioned, which were plotted to facilitate the analysis.
# Then, to obtain an indicator of the density of Italian restaurants, the central coordinate of the locations was calculated to obtain the average values of longitude and latitude. Then, I averaged the Euclidean distance from each location to the average coordinates. That was my indicator; average distance to the average coordinate.

# %% [markdown]
# ### Results

# %% [markdown]
# Below, we can see that all cities have a large number of Italian restaurants, and that competition is strong in the neighborhood.
# The maps were generated in the geoplot with folio:

# %%
# import labrarys
import numpy as np
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import folium # map rendering library

# %%
# Forsquare credentials
CLIENT_ID = 'EQXNTOCMHQ2XTDFKEJ1BGUX1EHURHKCE4BBZUWSRAWD0NQAC' # your Foursquare ID
CLIENT_SECRET = 'W5JK30GFNMI50HH3VSALF2CHDXAF5BXP2TV5QRITEFXQ1NMC' # your Foursquare Secret
VERSION = '20180323'

# %%
# Find data from São Paulo (Brazil), Rio de Janiero (Brazil)
LIMIT = 500 # Maximum is 100
cities = ['São Paulo, SP', "Porto Alegre, RS", "Florianópolis, SC", "Curitiba, PR", "Rio de Janeiro, RJ"]
results = {}
for city in cities:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&categoryId={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        city,
        LIMIT,
        "4bf58dd8d48988d110941735") # Italian Food CATEGORY ID
    results[city] = requests.get(url).json()

# %%
results
# Out:
# {'São Paulo, SP': {'meta': {'code': 200,
#    'requestId': '5ea7c59f6d8c560027c01ce4'},
#   'response': {'suggestedFilters': {'header': 'Tap to show:',
#     'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#    'geocode': {'what': '',
#     'where': 'são paulo sp',
#     'center': {'lat': -23.5475, 'lng': -46.63611},
#     'displayString': 'São Paulo, SP, Brazil',
#     'cc': 'BR',
#     'geometry': {'bounds': {'ne': {'lat': -23.356903009710976,
#        'lng': -46.36505302809169},
#       'sw': {'lat': -24.007316994733713, 'lng': -46.82635794604196}}},
#     'slug': 'sao-paulo',
#     'longId': '72057594041376375'},
#    'headerLocation': 'São Paulo',
#    'headerFullLocation': 'São Paulo',
#    'headerLocationGranularity': 'city',
#    'query': 'italian',
#    'totalResults': 188,
#    'suggestedBounds': {'ne': {'lat': -23.466525905651366,
#      'lng': -46.529600349001825},
#     'sw': {'lat': -23.655072360285345, 'lng': -46.72037303641319}},
#    'groups': [{'type': 'Recommended Places',
#      'name': 'recommended',
#      'items': [{'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b7c8c03f964a520339a2fe3',
#         'name': 'Famiglia Mancini',
#         'contact': {},
#         'location': {'address': 'R. Avanhandava, 25',
#          'lat': -23.550301904247608,
#          'lng': -46.64522871268116,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.550301904247608,
#            'lng': -46.64522871268116}],
#          'postalCode': '01306-001',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Avanhandava, 25',
#           'São Paulo, SP',
#           '01306-001',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b7c8c03f964a520339a2fe3-0'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b7a0e03f964a52003212fe3',
#         'name': 'Due Cuochi Cucina',
#         'contact': {},
#         'location': {'address': 'R. Manuel Guedes, 93',
#          'lat': -23.581293409159883,
#          'lng': -46.679905117039716,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.581293409159883,
#            'lng': -46.679905117039716}],
#          'postalCode': '04536-070',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Manuel Guedes, 93',
#           'São Paulo, SP',
#           '04536-070',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b7a0e03f964a52003212fe3-1'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b8d31a4f964a52096ec32e3',
#         'name': 'Millesapori',
#         'contact': {},
#         'location': {'address': 'R. Pedroso Alvarenga, 1177',
#          'lat': -23.582823,
#          'lng': -46.681805,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.582823,
#            'lng': -46.681805}],
#          'postalCode': '04531-012',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Pedroso Alvarenga, 1177',
#           'São Paulo, SP',
#           '04531-012',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b8d31a4f964a52096ec32e3-2'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '55b78851498e8e6f8631db81',
#         'name': 'Nino Cucina & Vino',
#         'contact': {},
#         'location': {'address': 'R. Jerônimo da Veiga, 30',
#          'lat': -23.58092433505544,
#          'lng': -46.67928946432996,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.58092433505544,
#            'lng': -46.67928946432996}],
#          'postalCode': '04536-000',
#          'cc': 'BR',
#          'neighborhood': 'Jd. Europa',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Jerônimo da Veiga, 30',
#           'São Paulo, SP',
#           '04536-000',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': True,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '135632602'},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-55b78851498e8e6f8631db81-3'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b6e2516f964a52099ad2ce3',
#         'name': 'Due Cuochi Cucina',
#         'contact': {},
#         'location': {'address': 'Shopping Cidade Jardim',
#          'crossStreet': '3º Piso',
#          'lat': -23.599056709371265,
#          'lng': -46.69734404493315,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.599056709371265,
#            'lng': -46.69734404493315}],
#          'postalCode': '05676-120',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['Shopping Cidade Jardim (3º Piso)',
#           'São Paulo, SP',
#           '05676-120',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b6e2516f964a52099ad2ce3-4'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '51f93e65498e34b765ec0d41',
#         'name': 'Sapore Italia',
#         'contact': {},
#         'location': {'address': 'R. Américo Brasiliense, 1216',
#          'lat': -23.633211492155883,
#          'lng': -46.69880390167236,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.633211492155883,
#            'lng': -46.69880390167236}],
#          'postalCode': '04715-002',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Américo Brasiliense, 1216',
#           'São Paulo, SP',
#           '04715-002',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-51f93e65498e34b765ec0d41-5'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b677605f964a52060502be3',
#         'name': 'Jardim de Napoli',
#         'contact': {},
#         'location': {'address': 'R. Dr. Martinico Prado, 463',
#          'crossStreet': 'Av. Angélica',
#          'lat': -23.542636148268116,
#          'lng': -46.655837791097724,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.542636148268116,
#            'lng': -46.655837791097724}],
#          'postalCode': '01224-011',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Dr. Martinico Prado, 463 (Av. Angélica)',
#           'São Paulo, SP',
#           '01224-011',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b677605f964a52060502be3-6'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bafbac4f964a520b91b3ce3',
#         'name': 'Sallvattore',
#         'contact': {},
#         'location': {'address': 'R. Salvador Cardoso, 131',
#          'crossStreet': 'R. Cojuba',
#          'lat': -23.58712661347276,
#          'lng': -46.68544664707893,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.58712661347276,
#            'lng': -46.68544664707893}],
#          'postalCode': '04533-050',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Salvador Cardoso, 131 (R. Cojuba)',
#           'São Paulo, SP',
#           '04533-050',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4bafbac4f964a520b91b3ce3-7'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c6ffb32d97fa1431881f4ca',
#         'name': 'La Cucina di Casa',
#         'contact': {},
#         'location': {'address': "R. Gabriele D'annunzio, 1324",
#          'crossStreet': 'R. Vicente Leporace',
#          'lat': -23.6263147372704,
#          'lng': -46.67177443168689,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.6263147372704,
#            'lng': -46.67177443168689}],
#          'postalCode': '04619-005',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ["R. Gabriele D'annunzio, 1324 (R. Vicente Leporace)",
#           'São Paulo, SP',
#           '04619-005',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4c6ffb32d97fa1431881f4ca-8'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4cb4abfbef1b37045aae5a00',
#         'name': 'Agello Cucina',
#         'contact': {},
#         'location': {'address': 'R. Sônia Ribeiro, 33',
#          'crossStreet': 'R. Edson',
#          'lat': -23.626142881194994,
#          'lng': -46.669757643642214,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.626142881194994,
#            'lng': -46.669757643642214}],
#          'postalCode': '04620-020',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Sônia Ribeiro, 33 (R. Edson)',
#           'São Paulo, SP',
#           '04620-020',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4cb4abfbef1b37045aae5a00-9'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4be6d328d4f7c9b662142720',
#         'name': 'Pastifício Primo',
#         'contact': {},
#         'location': {'address': 'R. Fradique Coutinho, 211',
#          'crossStreet': 'R. Artur de Azevedo',
#          'lat': -23.564700292069386,
#          'lng': -46.68535713354704,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.564700292069386,
#            'lng': -46.68535713354704}],
#          'postalCode': '05416-010',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Fradique Coutinho, 211 (R. Artur de Azevedo)',
#           'São Paulo, SP',
#           '05416-010',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4be6d328d4f7c9b662142720-10'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b54929cf964a520a3c027e3',
#         'name': 'Cantina Gigio',
#         'contact': {},
#         'location': {'address': 'R. dos Pinheiros, 355',
#          'lat': -23.56514787518048,
#          'lng': -46.6817181956725,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.56514787518048,
#            'lng': -46.6817181956725}],
#          'postalCode': '05422-010',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. dos Pinheiros, 355',
#           'São Paulo, SP',
#           '05422-010',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b54929cf964a520a3c027e3-11'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '55302a52498e6d7e6bdddca0',
#         'name': 'Eataly',
#         'contact': {},
#         'location': {'address': 'Av. Pres. Juscelino Kubitschek, 1489',
#          'lat': -23.591340916236412,
#          'lng': -46.68339228998862,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.591340916236412,
#            'lng': -46.68339228998862}],
#          'postalCode': '04543-011',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['Av. Pres. Juscelino Kubitschek, 1489',
#           'São Paulo, SP',
#           '04543-011',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d1f5941735',
#           'name': 'Gourmet Shop',
#           'pluralName': 'Gourmet Shops',
#           'shortName': 'Gourmet',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-55302a52498e6d7e6bdddca0-12'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b1b0f0ff964a5205cf723e3',
#         'name': 'Zucco',
#         'contact': {},
#         'location': {'address': 'R. Haddock Lobo, 1416',
#          'lat': -23.563278829911784,
#          'lng': -46.667273001325476,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.563278829911784,
#            'lng': -46.667273001325476}],
#          'postalCode': '01414-002',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Haddock Lobo, 1416',
#           'São Paulo, SP',
#           '01414-002',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b1b0f0ff964a5205cf723e3-13'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4cc483e91e596dcb5217d267',
#         'name': 'Casa da Fogazza - Seu Zé',
#         'contact': {},
#         'location': {'address': 'R. Alto Rio Novo, 137',
#          'lat': -23.570517161043046,
#          'lng': -46.574785237144425,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.570517161043046,
#            'lng': -46.574785237144425}],
#          'postalCode': '03191-060',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Alto Rio Novo, 137',
#           'São Paulo, SP',
#           '03191-060',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4cc483e91e596dcb5217d267-14'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b7a1539f964a52040222fe3',
#         'name': 'Tatini',
#         'contact': {},
#         'location': {'address': 'R. Batataes, 558',
#          'lat': -23.569382241449443,
#          'lng': -46.658222966020624,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.569382241449443,
#            'lng': -46.658222966020624}],
#          'postalCode': '01423-010',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Batataes, 558',
#           'São Paulo, SP',
#           '01423-010',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b7a1539f964a52040222fe3-15'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4cf0599df98ba09003c1c673',
#         'name': 'Bella Ciao Rotisserie',
#         'contact': {},
#         'location': {'address': 'R. Mateus Leme, 266',
#          'lat': -23.484322421005388,
#          'lng': -46.627119149996744,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.484322421005388,
#            'lng': -46.627119149996744}],
#          'postalCode': '02408-080',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Mateus Leme, 266',
#           'São Paulo, SP',
#           '02408-080',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4cf0599df98ba09003c1c673-16'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '51f5c3e5498e433bcb9bf929',
#         'name': 'Restaurante Emiliano',
#         'contact': {},
#         'location': {'address': 'Rua Oscar Freire, 384',
#          'lat': -23.56616142042552,
#          'lng': -46.66538474859159,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.56616142042552,
#            'lng': -46.66538474859159}],
#          'postalCode': '01426-000',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['Rua Oscar Freire, 384',
#           'São Paulo, SP',
#           '01426-000',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-51f5c3e5498e433bcb9bf929-17'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c546358fd2ea5934799052a',
#         'name': 'Lo Spaghetto Cantina',
#         'contact': {},
#         'location': {'address': 'R Emílio Mallet, 883',
#          'lat': -23.54648442362847,
#          'lng': -46.56524252435255,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.54648442362847,
#            'lng': -46.56524252435255}],
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R Emílio Mallet, 883',
#           'São Paulo, SP',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4c546358fd2ea5934799052a-18'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '557b70bc498ebf798b8d4a52',
#         'name': 'Seo Zé Fogazza',
#         'contact': {},
#         'location': {'address': 'R. Capituba, 85',
#          'crossStreet': 'R. Miragem',
#          'lat': -23.560218212910236,
#          'lng': -46.57020816512193,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.560218212910236,
#            'lng': -46.57020816512193}],
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Capituba, 85 (R. Miragem)',
#           'São Paulo, SP',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-557b70bc498ebf798b8d4a52-19'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4cd06ba76200b1f7802cd428',
#         'name': "Popo's Focaccia",
#         'contact': {},
#         'location': {'address': 'R. Guaimbé, 675',
#          'lat': -23.566891706820652,
#          'lng': -46.594843402760546,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.566891706820652,
#            'lng': -46.594843402760546}],
#          'postalCode': '03118-030',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Guaimbé, 675',
#           'São Paulo, SP',
#           '03118-030',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4cd06ba76200b1f7802cd428-20'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4d458492e198721eafa9c68b',
#         'name': 'Osteria Generale',
#         'contact': {},
#         'location': {'address': 'R. Dr. Fausto Ferraz, 163',
#          'lat': -23.565734284377985,
#          'lng': -46.64679178268468,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.565734284377985,
#            'lng': -46.64679178268468}],
#          'postalCode': '01333-030',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Dr. Fausto Ferraz, 163',
#           'São Paulo, SP',
#           '01333-030',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4d458492e198721eafa9c68b-21'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b67882cf964a52006542be3',
#         'name': 'La Pergoletta',
#         'contact': {},
#         'location': {'address': 'R. Itapura, 1478',
#          'lat': -23.551802,
#          'lng': -46.56477,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.551802,
#            'lng': -46.56477}],
#          'postalCode': '03310-000',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Itapura, 1478',
#           'São Paulo, SP',
#           '03310-000',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': True,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '561193273'},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b67882cf964a52006542be3-22'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '53eb7bec498e82ed0881b060',
#         'name': 'Vapiano',
#         'contact': {},
#         'location': {'address': 'R. Joaquim Floriano, 422',
#          'lat': -23.584365795236952,
#          'lng': -46.67409322846317,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.584365795236952,
#            'lng': -46.67409322846317}],
#          'postalCode': '04534-002',
#          'cc': 'BR',
#          'neighborhood': 'Itaim Bibi, São Paulo, SP',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Joaquim Floriano, 422',
#           'São Paulo, SP',
#           '04534-002',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': True,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-53eb7bec498e82ed0881b060-23'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b8f26e3f964a520594b33e3',
#         'name': 'Restaurante Gero',
#         'contact': {},
#         'location': {'address': 'R. Haddock Lobo, 1629',
#          'lat': -23.564746739395257,
#          'lng': -46.66869673494163,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.564746739395257,
#            'lng': -46.66869673494163}],
#          'postalCode': '01414-003',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Haddock Lobo, 1629',
#           'São Paulo, SP',
#           '01414-003',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b8f26e3f964a520594b33e3-24'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5825ef822fea3661eaa2d23a',
#         'name': 'Modern Mamma Osteria',
#         'contact': {},
#         'location': {'address': 'R. Manuel Guedes, 160',
#          'lat': -23.581859974991648,
#          'lng': -46.67969178736766,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.581859974991648,
#            'lng': -46.67969178736766}],
#          'postalCode': '04536-070',
#          'cc': 'BR',
#          'neighborhood': 'Itaim Bibi',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Manuel Guedes, 160',
#           'São Paulo, SP',
#           '04536-070',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-5825ef822fea3661eaa2d23a-25'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b6f2d86f964a52048e22ce3',
#         'name': 'La Tambouille',
#         'contact': {},
#         'location': {'address': 'Av. Nove de Julho, 5925',
#          'lat': -23.580618552238494,
#          'lng': -46.6817412047768,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.580618552238494,
#            'lng': -46.6817412047768}],
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['Av. Nove de Julho, 5925',
#           'São Paulo, SP',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b6f2d86f964a52048e22ce3-26'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '54d23539498ea9bbdccf54a1',
#         'name': 'De Caprio Massas Artesanais',
#         'contact': {},
#         'location': {'address': 'R. Cotoxó, 410 e 422',
#          'crossStreet': 'rua ministro ferreira alves',
#          'lat': -23.530722870397884,
#          'lng': -46.683988748610936,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.530722870397884,
#            'lng': -46.683988748610936}],
#          'postalCode': '05021-000',
#          'cc': 'BR',
#          'neighborhood': 'Vila Pompéia',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Cotoxó, 410 e 422 (rua ministro ferreira alves)',
#           'São Paulo, SP',
#           '05021-000',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': True,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '428911766'},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-54d23539498ea9bbdccf54a1-27'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b6e0847f964a520e9a42ce3',
#         'name': 'Vicolo Nostro',
#         'contact': {},
#         'location': {'address': 'R. Jataituba, 29',
#          'crossStreet': 'R. das Margaridas',
#          'lat': -23.62394311191654,
#          'lng': -46.688594472932365,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.62394311191654,
#            'lng': -46.688594472932365}],
#          'postalCode': '04704-090',
#          'cc': 'BR',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Jataituba, 29 (R. das Margaridas)',
#           'São Paulo, SP',
#           '04704-090',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b6e0847f964a520e9a42ce3-28'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '57545ae4cd10585cbfbc424a',
#         'name': 'Des Cucina',
#         'contact': {},
#         'location': {'address': 'R. Des. do Vale, 233',
#          'lat': -23.532498,
#          'lng': -46.683746,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.532498,
#            'lng': -46.683746}],
#          'postalCode': '05010-040',
#          'cc': 'BR',
#          'neighborhood': 'Vila Pompéia',
#          'city': 'São Paulo',
#          'state': 'SP',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Des. do Vale, 233',
# ...
#         'contact': {},
#         'location': {'address': 'R. Vde. de Pirajá, 229',
#          'lat': -22.984377444007876,
#          'lng': -43.202194116364446,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -22.984377444007876,
#            'lng': -43.202194116364446}],
#          'postalCode': '22410-001',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Vde. de Pirajá, 229',
#           'Rio de Janeiro, RJ',
#           '22410-001',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d1c9941735',
#           'name': 'Ice Cream Shop',
#           'pluralName': 'Ice Cream Shops',
#           'shortName': 'Ice Cream',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4d160b0a302da1cd4a98b393-90'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '55a2ba33498eb8d1da83f28f',
#         'name': 'Di Grano - Fábrica Di Pasta',
#         'contact': {},
#         'location': {'address': 'R. Aníbal de Mendonça 55 - Loja B',
#          'crossStreet': 'R. Prudente de Morais',
#          'lat': -22.984806483663657,
#          'lng': -43.211410120012964,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -22.984806483663657,
#            'lng': -43.211410120012964}],
#          'postalCode': '22410-050',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Aníbal de Mendonça 55 - Loja B (R. Prudente de Morais)',
#           'Rio de Janeiro, RJ',
#           '22410-050',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-55a2ba33498eb8d1da83f28f-91'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c40f4cfda3dc9289d34c8b9',
#         'name': 'Azzurra Ristorante',
#         'contact': {},
#         'location': {'address': 'Rio Design Barra',
#          'crossStreet': 'Piso 3',
#          'lat': -23.001216372573843,
#          'lng': -43.38553895059992,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.001216372573843,
#            'lng': -43.38553895059992}],
#          'postalCode': '22793-081',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['Rio Design Barra (Piso 3)',
#           'Rio de Janeiro, RJ',
#           '22793-081',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': True,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '87119218'},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4c40f4cfda3dc9289d34c8b9-92'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '55809299498e942cd1d68cf6',
#         'name': 'Simon Boccanegra Osteria',
#         'contact': {},
#         'location': {'address': 'R. Aires Saldanha, 98B',
#          'crossStreet': 'R. Miguel Lemos',
#          'lat': -22.9785686527827,
#          'lng': -43.18990433038352,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -22.9785686527827,
#            'lng': -43.18990433038352}],
#          'postalCode': '22060-030',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Aires Saldanha, 98B (R. Miguel Lemos)',
#           'Rio de Janeiro, RJ',
#           '22060-030',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-55809299498e942cd1d68cf6-93'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4d322ed2c75a6ea898b50bae',
#         'name': 'Follie Italiane',
#         'contact': {},
#         'location': {'address': 'Estr. dos Bandeirantes, 23034',
#          'lat': -22.982848590797694,
#          'lng': -43.489477957367896,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -22.982848590797694,
#            'lng': -43.489477957367896}],
#          'postalCode': '22785-092',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['Estr. dos Bandeirantes, 23034',
#           'Rio de Janeiro, RJ',
#           '22785-092',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4d322ed2c75a6ea898b50bae-94'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b3ba671f964a520fd7725e3',
#         'name': 'La Mole',
#         'contact': {},
#         'location': {'address': 'Av. Armando Lombardi, 205',
#          'lat': -23.00746474383264,
#          'lng': -43.306601769827054,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -23.00746474383264,
#            'lng': -43.306601769827054}],
#          'postalCode': '22640-020',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['Av. Armando Lombardi, 205',
#           'Rio de Janeiro, RJ',
#           '22640-020',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b3ba671f964a520fd7725e3-95'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5a1c2e8cc0af5707fb3f1d72',
#         'name': 'Fiammetta',
#         'contact': {},
#         'location': {'address': 'Via Parque Shopping',
#          'crossStreet': '2º Piso',
#          'lat': -22.983037429973926,
#          'lng': -43.36216645972532,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -22.983037429973926,
#            'lng': -43.36216645972532}],
#          'postalCode': '22775-904',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['Via Parque Shopping (2º Piso)',
#           'Rio de Janeiro, RJ',
#           '22775-904',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-5a1c2e8cc0af5707fb3f1d72-96'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4cbe16d1a0c4f04d1a394d31',
#         'name': 'Bonna Pizza',
#         'contact': {},
#         'location': {'address': 'R. Gabriel Habbib, 225',
#          'lat': -22.91301955183642,
#          'lng': -43.542034505548855,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -22.91301955183642,
#            'lng': -43.542034505548855}],
#          'postalCode': '23016-190',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Gabriel Habbib, 225',
#           'Rio de Janeiro, RJ',
#           '23016-190',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4cbe16d1a0c4f04d1a394d31-97'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '583b754b13bb7732cec76a08',
#         'name': "L'ulivo Cucina e Vini",
#         'contact': {},
#         'location': {'address': 'R. Miguel Lemos, 54, Lj. B',
#          'lat': -22.977759686552393,
#          'lng': -43.191403536343586,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -22.977759686552393,
#            'lng': -43.191403536343586}],
#          'postalCode': '22071-001',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Miguel Lemos, 54, Lj. B',
#           'Rio de Janeiro, RJ',
#           '22071-001',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-583b754b13bb7732cec76a08-98'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b058726f964a520358222e3',
#         'name': 'Capricciosa',
#         'contact': {},
#         'location': {'address': 'R. Vinícius de Moraes, 134',
#          'crossStreet': 'R. Br. da Torre',
#          'lat': -22.983315902981605,
#          'lng': -43.202675658285884,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': -22.983315902981605,
#            'lng': -43.202675658285884}],
#          'postalCode': '22411-010',
#          'cc': 'BR',
#          'city': 'Rio de Janeiro',
#          'state': 'RJ',
#          'country': 'Brasil',
#          'formattedAddress': ['R. Vinícius de Moraes, 134 (R. Br. da Torre)',
#           'Rio de Janeiro, RJ',
#           '22411-010',
#           'Brasil']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'verified': False,
#         'stats': {'tipCount': 0,
#          'usersCount': 0,
#          'checkinsCount': 0,
#          'visitsCount': 0},
#         'beenHere': {'count': 0,
#          'lastCheckinExpiredAt': 0,
#          'marked': False,
#          'unconfirmedCount': 0},
#         'photos': {'count': 0, 'groups': []},
#         'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#        'referralId': 'e-0-4b058726f964a520358222e3-99'}]}]}}}

# %%
len(results)
# Out:
# 5

# %%
# The Foursquare API Only gives us the nearest 100 venues in the city.
df_venues={}
for city in cities:
    venues = json_normalize(results[city]['response']['groups'][0]['items'])
    df_venues[city] = venues[['venue.name', 'venue.location.address', 'venue.location.lat', 'venue.location.lng']]
    df_venues[city].columns = ['Name', 'Address', 'Lat', 'Lng']
# Out:
# /home/andrenote2/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.

# %%
maps = {}
for city in cities:
    city_lat = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    city_lng = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps[city] = folium.Map(location=[city_lat, city_lng], zoom_start=11)

    # add markers to map
    for lat, lng, label in zip(df_venues[city]['Lat'], df_venues[city]['Lng'], df_venues[city]['Name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(maps[city])  
    print(f"Total number of pizza places in {city} = ", results[city]['response']['totalResults'])
    print("Showing Top 100")
# Out:
# Total number of pizza places in São Paulo, SP =  188
# Showing Top 100
# Total number of pizza places in Porto Alegre, RS =  87
# Showing Top 100
# Total number of pizza places in Florianópolis, SC =  68
# Showing Top 100
# Total number of pizza places in Curitiba, PR =  104
# Showing Top 100
# Total number of pizza places in Rio de Janeiro, RJ =  115
# Showing Top 100

# %% [markdown]
# Below, we can see that all cities have a large number of Italian restaurants, and that competition is strong in the neighborhood.
# The maps were generated in the geoplot with folio:

# %% [markdown]
# #### São Paulo

# %%
maps[cities[0]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Porto Alegre

# %%
maps[cities[1]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Florianópolis

# %%
maps[cities[2]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Curitiba

# %%
maps[cities[3]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Rio de Janeiro

# %%
maps[cities[4]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Analysis of Results (only establishments registered on Foursquare)
# - Total number of pizza places in São Paulo, SP = 188
# - Total number of pizza places in Porto Alegre, RS = 85
# - Total number of pizza places in Florianópolis, SC = 68
# - Total number of pizza places in Curitiba, PR = 104
# - Total number of pizza places in Rio de Janeiro, RJ = 115
#
# Upon First inspection we see that São Paulo, Curitiba, Porto Alegre and Florianópolis are the most densely cities. In the next phase we Calculate the Mean coordinate and the mean distance to mean coordinate(MDMC). We represent the mean coordinate with a big green circle and distances with green line

# %%
maps = {}
for city in cities:
    city_lat = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    city_lng = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps[city] = folium.Map(location=[city_lat, city_lng], zoom_start=11)
    venues_mean_coor = [df_venues[city]['Lat'].mean(), df_venues[city]['Lng'].mean()] 
    # add markers to map
    for lat, lng, label in zip(df_venues[city]['Lat'], df_venues[city]['Lng'], df_venues[city]['Name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(maps[city])
        folium.PolyLine([venues_mean_coor, [lat, lng]], color="green", weight=1.5, opacity=0.5).add_to(maps[city])
    
    label = folium.Popup("Mean Co-ordinate", parse_html=True)
    folium.CircleMarker(
        venues_mean_coor,
        radius=10,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(maps[city])

    print(city)
    print("Mean Distance from Mean coordinates")
    print(np.mean(np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coor),1,df_venues[city][['Lat','Lng']].values)))
# Out:
# São Paulo, SP
# Mean Distance from Mean coordinates
# 0.03834513392561405
# Porto Alegre, RS
# Mean Distance from Mean coordinates
# 0.03106063987001945
# Florianópolis, SC
# Mean Distance from Mean coordinates
# 0.08019835743825189
# Curitiba, PR
# Mean Distance from Mean coordinates
# 0.027956087712631295
# Rio de Janeiro, RJ
# Mean Distance from Mean coordinates
# 0.09823943423737182

# %% [markdown]
# ### São Paulo

# %%
maps[cities[0]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Porto Alegre

# %%
maps[cities[1]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Florianópolis

# %%
maps[cities[2]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Curitiba

# %%
maps[cities[3]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Rio de Janeiro

# %%
maps[cities[4]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Results - Mean Distance from Mean coordinates:
# - Curitiba, PR: 0.027956087712631295;
# - Porto Alegre, RS: 0.03108649945434047;
# - São Paulo, SP: 0.03834513392561405;
# - Florianópolis, SC: 0.07987321369324735;
# - Rio de Janeiro, RJ: 0.09823943423737182

# %% [markdown]
# ## Discussion

# %% [markdown]
# We can see that São Paulo is the city with the largest number of establishments specializing in Italian food. The cities of southern Brazil also have a significant number of establishments.
# Another important factor is the population of these capitals, the most significant of which are São Paulo and Rio de Janeiro, respectively.
# We visually perceive that the density is concentrated in the shopping centers of these capitals, except in Rio de Janeiro, where the restaurants are far away.
# To get a concrete measure of this density, we will use some basic statistics. I will get the average location of the establishments
# Next, I will take the average distance from the locations to the average coordinates.
# In a simplified way, Italian restaurants are crowded in most capitals, except in Rio de Janeiro.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Taking into account that the consultancy was hired to analyze the best city for opening a restaurant away from the competition, we easily concluded that Rio de Janeiro is the only city with Italian food on every corner. That way, there is plenty of space to cook pasta and make money away from the competition in all other cities.
# Buon appetito!
